# %% [markdown]
# <a href="https://colab.research.google.com/github/kmodi1428/ML_Assignment/blob/main/Simple_LR_Salary_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Salary_hike -> Build a prediction model for Salary_hike

# %%
# Salary data

df = pd.read_csv("/content/Salary_Data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
# check null value
df.isna().sum()

# there are no null values
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.subplots(figsize=(10,5))
plt.subplot(121)
plt.boxplot(df['YearsExperience'])
plt.title("Years_Experience" , c='red')
plt.subplot(122)
plt.boxplot(df['Salary'])
plt.title("Salary" , c = 'red')
plt.show()

#(there are no Outliers)
# Out:
# <ipython-input-10-d7464094f750>:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(121)

# %%
plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (10,5))
plt.scatter(df['YearsExperience'],df['Salary'],c = 'black',marker = '*')
plt.xlabel('Years_Experience',c = 'blue')
plt.ylabel('Salary',c = 'blue')

# graph is look like liner form
# Out:
# <ipython-input-30-eb5d30e49074>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# Text(0, 0.5, 'Salary')

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
#  OLS Modeling

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_log_error
import statsmodels.formula.api as sfa

# %%
model_1 = sfa.ols('Salary~YearsExperience' , data = df).fit()
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Fri, 01 Dec 2023   Prob (F-statistic):           1.14e-20
# Time:                        14:40:44   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
model_2 = sfa.ols('Salary~np.sqrt(YearsExperience)', data = df).fit()
model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     377.8
# Date:                Fri, 01 Dec 2023   Prob (F-statistic):           8.57e-18
# Time:                        14:42:05   Log-Likelihood:                -308.52
# No. Observations:                  30   AIC:                             621.0
# Df Residuals:                      28   BIC:                             623.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
model_3 = sfa.ols('Salary~np.log(YearsExperience)', data = df).fit()
model_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     163.6
# Date:                Fri, 01 Dec 2023   Prob (F-statistic):           3.25e-13
# Time:                        14:41:52   Log-Likelihood:                -319.77
# No. Observations:                  30   AIC:                             643.5
# Df Residuals:                      28   BIC:                             646.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
model_4 = sfa.ols("Salary~np.cbrt(YearsExperience)",data = df).fit()
model_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     287.7
# Date:                Fri, 01 Dec 2023   Prob (F-statistic):           2.91e-16
# Time:                        14:46:28   Log-Likelihood:                -312.29
# No. Observations:                  30   AIC:                             628.6
# Df Residuals:                      28   BIC:                             631.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
# we can see the different r2_scores, so we can consider the highest one i.e model_1

plt.style.use('seaborn-darkgrid')
plt.figure(figsize = (10,6))
plt.scatter(df['YearsExperience'],df['Salary'],c = 'black',marker = '*')
plt.plot(df['YearsExperience'],model_1.predict(),c = 'red')
plt.xlabel('YearExperience', c = 'blue')
plt.ylabel('Salary', c = 'blue')
# Out:
# <ipython-input-32-3635bfa01b18>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# Text(0, 0.5, 'Salary')

# %%
predicted = pd.DataFrame()
predicted['YearsExperience'] = df['YearsExperience']
predicted['Salary'] = df['Salary']
predicted['Predicted_Salary'] = model_1.predict()
predicted
# Out:
#     YearsExperience    Salary  Predicted_Salary
# 0               1.1   39343.0      36187.158752
# 1               1.3   46205.0      38077.151217
# 2               1.5   37731.0      39967.143681
# 3               2.0   43525.0      44692.124842
# 4               2.2   39891.0      46582.117306
# 5               2.9   56642.0      53197.090931
# 6               3.0   60150.0      54142.087163
# 7               3.2   54445.0      56032.079627
# 8               3.2   64445.0      56032.079627
# 9               3.7   57189.0      60757.060788
# 10              3.9   63218.0      62647.053252
# 11              4.0   55794.0      63592.049484
# 12              4.0   56957.0      63592.049484
# 13              4.1   57081.0      64537.045717
# 14              4.5   61111.0      68317.030645
# 15              4.9   67938.0      72097.015574
# 16              5.1   66029.0      73987.008038
# 17              5.3   83088.0      75877.000502
# 18              5.9   81363.0      81546.977895
# ...

# %%
actual = [df['Salary']]
predict = [predicted['Predicted_Salary']]
error = [x-y for x, y in zip(actual,predict)]
error
# Out:
# [0      3155.841248
#  1      8127.848783
#  2     -2236.143681
#  3     -1167.124842
#  4     -6691.117306
#  5      3444.909069
#  6      6007.912837
#  7     -1587.079627
#  8      8412.920373
#  9     -3568.060788
#  10      570.946748
#  11    -7798.049484
#  12    -6635.049484
#  13    -7456.045717
#  14    -7206.030645
#  15    -4159.015574
#  16    -7958.008038
#  17     7210.999498
#  18     -183.977895
#  19    11448.025873
#  20     1686.056015
#  21     5386.067319
#  22      855.097462
#  23    10530.108765
#  24     1424.127605
#  25    -5259.861092
#  26     1402.157748
#  27    -3876.838485
#  28     -735.812110
#  29    -3144.804574
#  dtype: float64]

# %%
plt.scatter(df['Salary'],error, c= 'black' , marker = '*')
plt.xlabel('Salary', c= 'blue')
plt.ylabel('Error', c = 'blue')

# here we can see that there is no correlaltion between the error and the variable
# Out:
# Text(0, 0.5, 'Error')
